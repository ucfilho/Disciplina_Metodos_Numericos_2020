# %% [markdown]
# <a href="https://colab.research.google.com/github/ucfilho/Disciplina_Metodos_Numericos_2020/blob/master/Mod_03_class_11_obtendo_cin%C3%A9tica_out_13_2020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from IPython.display import YouTubeVideo

# %% [markdown]
# Após produzir 10 kg de  uma substância azul misteriosa, Walter White pede para Jesse Pinkman armazenar a substância em um local seguro. No entanto, Jesse armazena o material em um local inadequado, o que faz com que ele se degrade ao longo do tempo. Caso A representa a massa do material e k é uma constante considere que a taxa de degradação é dada por: $ \frac{dA}{dt} = −kA^n$ onde k é constante positiva. Após 15 dias, Walter analisa o produto e determina que restam 9.25 kg do material puro. Obtenha a cinética que descreve a massa da substância ao longo do tempo considere que as outras análises de Walter White para 30, 40 e 50 dias resultaram em 8.60,  8.22 e  7.87  kg.

# %%
# YT='yjw10sGPjTo'; YouTubeVideo(YT)
# YT='SUwPHTI47Lg'; YouTubeVideo(YT)
# YT='Qg9qcmiaPAo'; YouTubeVideo(YT)
