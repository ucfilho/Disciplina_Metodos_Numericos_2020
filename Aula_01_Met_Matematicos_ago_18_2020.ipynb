# %% [markdown]
# <a href="https://colab.research.google.com/github/ucfilho/Disciplina_Metodos_Numericos_2020/blob/master/Aula_01_Met_Matematicos_ago_18_2020.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# testando primeiros
print('Hello world')
print('Hello world, I am evolving')
# Out:
# Hello world
# Hello world, I am evolving

# %% [markdown]
# $x=\frac{a}{b}$

# %%
for k in range(2):
  for i in range(2):
    for j in range(2):
      print('k=',k,'i=',i,'j=',j)
# Out:
# k= 0 i= 0 j= 0
# k= 0 i= 0 j= 1
# k= 0 i= 1 j= 0
# k= 0 i= 1 j= 1
# k= 1 i= 0 j= 0
# k= 1 i= 0 j= 1
# k= 1 i= 1 j= 0
# k= 1 i= 1 j= 1

# %%
for k in range(2):
  for i in range(2):
    for j in range(2):
      print('k=',k,'i=',i,'j=',j)
  print('===================')
# Out:
# k= 0 i= 0 j= 0
# k= 0 i= 0 j= 1
# k= 0 i= 1 j= 0
# k= 0 i= 1 j= 1
# ...
# k= 1 i= 0 j= 0
# k= 1 i= 0 j= 1
# k= 1 i= 1 j= 0
# k= 1 i= 1 j= 1
# ...

# %%
x=[] # lista exemplo
for i in range(5):
  x.append(i)
print(x)
# Out:
# [0, 1, 2, 3, 4]

# %%
x=[] # lista exemplo
w=[]
for i in range(3):
  for j in range(3):
    x.append(j)
  w.append(x)
print(w)
# Out:
# [[0, 1, 2, 0, 1, 2, 0, 1, 2], [0, 1, 2, 0, 1, 2, 0, 1, 2], [0, 1, 2, 0, 1, 2, 0, 1, 2]]

# %%
 # lista exemplo
y=[]
for i in range(3):
  x=[]
  for j in range(3):
    x.append(j)
  y.append(x)
print(y)
# Out:
# [[0, 1, 2], [0, 1, 2], [0, 1, 2]]

# %%
print(y)
# Out:
# [[0, 1, 2], [0, 1, 2], [0, 1, 2]]

# %%
import pandas as pd
import numpy as np

# %%
df=pd.DataFrame(y)
print(df)
# Out:
#    0  1  2
# 0  0  1  2
# 1  0  1  2
# 2  0  1  2

# %%
mat=np.array(y)
print(mat)
# Out:
# [[0 1 2]
#  [0 1 2]
#  [0 1 2]]

# %%
mat[0,1]=99
print(mat)
# Out:
# [[ 0 99  2]
#  [ 0  1  2]
#  [ 0  1  2]]

# %%
print(mat[0,:])
# Out:
# [ 0 99  2]

# %%
print(mat[:,0])
# Out:
# [0 0 0]

# %%
# Recaptulando
# 1-tem o formato lista
# 2-tem o formato numpy array
# 3- tem o formato dataframe
# 4- indice começa no zero
# 5- tem varias situações que é possível converter formato
